# %%
from client_side import *
# Configurations
db_type="postgres"
host="localhost"
database="test_cli"
user="postgres"
password="postgres"
port="5438"
interval=10
# Out:
# Loading config from
# Loading config successful!
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='35e6f935-8260-4d71-8a9a-14da73600d7f'>
#   <div id="d7d100ed-2a69-497a-b27b-33faeb7d6c14" data-root-id="35e6f935-8260-4d71-8a9a-14da73600d7f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
connection = connect_db(db_type=db_type, host=host, database=database, user=user, password=password, port=port, interval=interval)
# Out:
# Configuration data sent successfully.

# %%
visualize(connection)
# Out:
# Row(sizing_mode='stretch_width')
#     [0] Column(width=300)
#         [0] Markdown(str, sizing_mode='stretch_width')
#         [1] HTML(str, sizing_mode='stretch_width')
#         [2] HTML(str, sizing_mode='stretch_width')
#         [3] HTML(str, sizing_mode='stretch_width')
#         [4] HTML(str, sizing_mode='stretch_width')
#         [5] HTML(str, sizing_mode='stretch_width')
#         [6] HTML(str, sizing_mode='stretch_width')
#         [7] HTML(str, sizing_mode='stretch_width')
#         [8] HTML(str, sizing_mode='stretch_width')
#         [9] HTML(str, sizing_mode='stretch_width')
#         [10] HTML(str, sizing_mode='stretch_width')
#         [11] HTML(str, sizing_mode='stretch_width')
#     [1] Column(sizing_mode='stretch_width')
#         [0] Markdown(str, sizing_mode='stretch_width')
#         [1] Row(sizing_mode='stretch_width')
#             [0] TextInput(name='Title', placeholder='Enter a string f..., width=220)
# ...
